# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./athlete_events.csv')

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
Olympic_data = data.drop(columns=['Name', 'Age', "Height", "Weight", "Games", "Season", "City", "Sport", "Event", "ID", "NOC"])

# %%
Olympic_data = Olympic_data.replace(0, np.nan)

# %%
Olympic_data = Olympic_data.dropna()
Olympic_data.reset_index(drop=True)
# Out:
#       Sex            Team  Year   Medal
# 0       M  Denmark/Sweden  1900    Gold
# 1       M         Finland  1920  Bronze
# 2       M         Finland  1920  Bronze
# 3       M         Finland  2014  Bronze
# 4       M         Finland  1948  Bronze
# 5       M         Finland  1948    Gold
# 6       M         Finland  1948    Gold
# 7       M         Finland  1948    Gold
# 8       M         Finland  1952  Bronze
# 9       M          Norway  1992    Gold
# 10      M          Norway  1992  Bronze
# 11      M          Norway  1994  Silver
# 12      M          Norway  1994  Bronze
# 13      M          Norway  1994  Silver
# 14      M          Norway  2002    Gold
# 15      M          Norway  2002    Gold
# 16      M          Norway  2006    Gold
# 17      F          Norway  2008    Gold
# 18      M          Norway  1920  Silver
# 19      F     Netherlands  1988  Bronze
# 20      M     Netherlands  1996  Silver
# 21      F          Norway  1996  Bronze
# ...
